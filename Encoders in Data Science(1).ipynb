# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/Users/nilesh/Encode_file.csv")

# %%
df
# Out:
#    age  Gender     bmi Dibetes     region
# 0   19    male  27.900     yes  southwest
# 1   18  female  33.770      no  southeast
# 2   28    male  33.000      no  southeast
# 3   33    male  22.705     yes  northwest
# 4   32    male  28.880      no  northwest
# 5   31  female  25.740      no  southeast
# 6   46  female  33.440     yes  southeast
# 7   37  female  27.740      no  northwest
# 8   37    male  29.830      no  northeast
# 9   60  female  25.840      no   northest

# %%
df.dtypes
# Out:
# age          int64
# Gender      object
# bmi        float64
# Dibetes     object
# region      object
# dtype: object

# %%
df[['Gender','Dibetes']] = df[['Gender','Dibetes']].astype('category')

# %%
df['region'] = df['region'].astype('category')

# %%
#df['region'] = df['region'].cat.codes

# %%
df.dtypes
# Out:
# age           int64
# Gender     category
# bmi         float64
# Dibetes    category
# region     category
# dtype: object

# %%
df['Gender'] = df['Gender'].cat.codes
df['Dibetes'] = df['Dibetes'].cat.codes

# %%
df
# Out:
#    age  Gender     bmi  Dibetes     region
# 0   19       1  27.900        1  southwest
# 1   18       0  33.770        0  southeast
# 2   28       1  33.000        0  southeast
# 3   33       1  22.705        1  northwest
# 4   32       1  28.880        0  northwest
# 5   31       0  25.740        0  southeast
# 6   46       0  33.440        1  southeast
# 7   37       0  27.740        0  northwest
# 8   37       1  29.830        0  northeast
# 9   60       0  25.840        0   northest

# %%
df = pd.get_dummies(df,columns=['region'])

# %%
df
# Out:
#    age  Gender     bmi  Dibetes  region_northeast  region_northest  \
# 0   19       1  27.900        1                 0                0
# 1   18       0  33.770        0                 0                0
# 2   28       1  33.000        0                 0                0
# 3   33       1  22.705        1                 0                0
# 4   32       1  28.880        0                 0                0
# 5   31       0  25.740        0                 0                0
# 6   46       0  33.440        1                 0                0
# 7   37       0  27.740        0                 0                0
# 8   37       1  29.830        0                 1                0
# 9   60       0  25.840        0                 0                1
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# ...

# %%
# !pip install category_encoders
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import category_encoders as ce

# %%
dfbin = df.copy()

# %%
bincode = ce.BinaryEncoder(dfbin,cols=['Gender','Dibetes','region'])

# %%
df_bin = bincode.fit_transform(dfbin)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-1b944fd18a12> in <module>()
# ...

# %%
df_bin.head(100)
